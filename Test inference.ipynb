# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *
# Out:
# C:\Users\richard\AppData\Local\conda\conda\envs\fastai\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
PATH = 'data/'
sz = 256

# %%
arch=resnet18
data = ImageClassifierData.from_paths(PATH, tfms=tfms_from_model(arch, sz))
learn = ConvLearner.pretrained(arch, data, precompute=False)
learn.load('epoch10')

# %%
#Then to predict the class of an image:
trn_tfms, val_tfms = tfms_from_model(arch,sz)
img = open_image('data/test1/option_0000.png')
im = val_tfms(img)
preds = learn.predict_array(im[None])
print(np.argmax(preds))
# Out:
# 1

# %%
os.listdir('data/test1')
# Out:
# ['option_0000.png',
#  'option_0001.png',
#  'option_0002.png',
#  'option_0003.png',
#  'option_0004.png',
#  'option_0005.png',
#  'option_0006.png',
#  'option_0007.png',
#  'option_0008.png',
#  'option_0009.png',
#  'option_0010.png',
#  'option_0011.png',
#  'option_0012.png',
#  'option_0013.png',
#  'option_0014.png',
#  'option_0015.png',
#  'option_0016.png',
#  'option_0017.png',
#  'option_0018.png',
#  'option_0019.png',
#  'option_0020.png',
#  'option_0021.png',
#  'option_0022.png',
#  'option_0023.png',
#  'option_0024.png',
#  'option_0025.png',
#  'option_0026.png',
#  'option_0027.png',
#  'option_0028.png',
#  'option_0029.png',
#  'option_0030.png',
#  'option_0031.png',
#  'option_0032.png',
#  'option_0033.png',
#  'option_0034.png',
#  'option_0035.png',
#  'option_0036.png',
#  'option_0037.png',
#  'option_0038.png',
#  'option_0039.png',
#  'option_0040.png',
#  'option_0041.png',
#  'option_0042.png',
#  'option_0043.png',
#  'option_0044.png',
# ...

# %%
preds
# Out:
# array([[-3.74354, -0.02395]], dtype=float32)

# %%
??open_image()

# %%
learn.predict(is_test=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-0d02944c61ce> in <module>()
# ----> 1 learn.predict(is_test=True)
#
# C:\code\alexis\fastai\learner.py in predict(self, is_test, use_swa)
#     371         dl = self.data.test_dl if is_test else self.data.val_dl
#     372         m = self.swa_model if use_swa else self.model
# --> 373         return predict(m, dl)
#     374
#     375     def predict_with_targs(self, is_test=False, use_swa=False):
#
# C:\code\alexis\fastai\model.py in predict(m, dl)
#     246
#     247 def predict(m, dl):
# --> 248     preda,_ = predict_with_targs_(m, dl)
#     249     return np.concatenate(preda)
#     250
#
# C:\code\alexis\fastai\model.py in predict_with_targs_(m, dl)
#     258     if hasattr(m, 'reset'): m.reset()
#     259     res = []
# ...

# %%
from model.deepaiplayer import *

# %%
learn
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (2): ReLU(inplace)
#   (3): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1), ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU(inplace)
# ...

# %%
images = [val_tfms(open_image('data/temp/' + file_name)) for file_name in os.listdir('data/temp')]

# %%
preds2 = [learn.predict_array(img[None])[0][0] for img in images]

# %%
np.argmax(preds2)
# Out:
# 474

# %%
len(preds2)
# Out:
# 547

# %%
preds[3][0]
# Out:
# array([-0.78221, -0.61137], dtype=float32)

# %%
img1
# Out:
# array([[[-2.1179 , -2.1179 , -2.1179 , ..., -2.1179 , -2.1179 , -2.1179 ],
#         [-2.1179 , -2.1179 , -2.1179 , ..., -2.1179 , -2.1179 , -2.1179 ],
#         [-2.1179 , -2.1179 , -2.1179 , ..., -2.1179 , -2.1179 , -2.1179 ],
#         ...,
#         [-2.1179 , -2.1179 , -2.1179 , ..., -2.1179 , -2.1179 , -2.1179 ],
#         [-2.1179 , -2.1179 , -2.1179 , ..., -2.1179 , -2.1179 , -2.1179 ],
#         [-2.1179 , -2.1179 , -2.1179 , ..., -2.1179 , -2.1179 , -2.1179 ]],
#
#        [[-2.03571, -2.03571, -2.03571, ..., -2.03571, -2.03571, -2.03571],
#         [-2.03571, -2.03571, -2.03571, ..., -2.03571, -2.03571, -2.03571],
#         [-2.03571, -2.03571, -2.03571, ..., -2.03571, -2.03571, -2.03571],
#         ...,
#         [-2.03571, -2.03571, -2.03571, ...,  1.7458 ,  1.7458 ,  1.7458 ],
#         [-2.03571, -2.03571, -2.03571, ...,  1.7458 ,  1.7458 ,  1.7458 ],
#         [-2.03571, -2.03571, -2.03571, ...,  1.7458 ,  1.7458 ,  1.7458 ]],
#
# ...
